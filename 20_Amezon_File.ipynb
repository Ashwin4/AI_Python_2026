# %% [markdown]
# This is AI Session #21 Amezon File analysis Total records 1465 rpw x 16 columans
# C:/Users/jaiam/OneDrive/2026/Training_2026/H2kInfosys-2026/AI_Data/amazon.csv

# %%
import pandas as pd

# %%
import sys

# %%
df=pd.read_csv("C:/Users/jaiam/OneDrive/2026/Training_2026/H2kInfosys-2026/AI_Data/amazon.csv")

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   str
#  4   actual_price         1465 non-null   str
#  5   discount_percentage  1465 non-null   str
#  6   rating               1465 non-null   str
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# dtypes: str(16)
# ...

# %%
print(sys.getsizeof(df))
# Out:
# 9292223

# %%
df.memory_usage()
# Out:
# Index                    132
# product_id             11720
# product_name           11720
# category               11720
# discounted_price       11720
# actual_price           11720
# discount_percentage    11720
# rating                 11720
# rating_count           11720
# about_product          11720
# user_id                11720
# user_name              11720
# review_id              11720
# review_title           11720
# review_content         11720
# img_link               11720
# product_link           11720
# dtype: int64

# %%
df.head()#First 5 rows
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.tail()#Last 5 rows
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# ...

# %%
#i want to check columns
print(df.columns)
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='str')

# %%
#i want only column product id
print(df['product_id'])
# Out:
# 0       B07JW9H4J1
# 1       B098NS6PVG
# 2       B096MSW6CT
# 3       B08HDJ86NZ
# 4       B08CF3B7N1
#            ...
# 1460    B08L7J3T31
# 1461    B01M6453MB
# 1462    B009P2LIL4
# 1463    B00J5DYCCA
# 1464    B01486F4G6
# Name: product_id, Length: 1465, dtype: str

# %%
#If we need only two Columns than add one more coma
print(df['product_id'],['product_name]'])
# Out:
# 0       B07JW9H4J1
# 1       B098NS6PVG
# 2       B096MSW6CT
# 3       B08HDJ86NZ
# 4       B08CF3B7N1
#            ...
# 1460    B08L7J3T31
# 1461    B01M6453MB
# 1462    B009P2LIL4
# 1463    B00J5DYCCA
# 1464    B01486F4G6
# Name: product_id, Length: 1465, dtype: str ['product_name]']

# %%
df['category']
# Out:
# 0       Computers&Accessories|Accessories&Peripherals|...
# 1       Computers&Accessories|Accessories&Peripherals|...
# 2       Computers&Accessories|Accessories&Peripherals|...
# 3       Computers&Accessories|Accessories&Peripherals|...
# 4       Computers&Accessories|Accessories&Peripherals|...
#                               ...
# 1460    Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# 1461    Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 1462    Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# 1463    Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# 1464    Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# Name: category, Length: 1465, dtype: str

# %%
df[['product_id','rating']]#Need to add extra [] for two and can write like this
# Out:
#       product_id rating
# 0     B07JW9H4J1    4.2
# 1     B098NS6PVG    4.0
# 2     B096MSW6CT    3.9
# 3     B08HDJ86NZ    4.2
# 4     B08CF3B7N1    4.2
# ...          ...    ...
# 1460  B08L7J3T31      4
# 1461  B01M6453MB    4.1
# 1462  B009P2LIL4    3.6
# 1463  B00J5DYCCA      4
# 1464  B01486F4G6    4.3
#
# [1465 rows x 2 columns]

# %%
df['actual_price']
# Out:
# 0       ₹1,099
# 1         ₹349
# 2       ₹1,899
# 3         ₹699
# 4         ₹399
#          ...
# 1460      ₹919
# 1461    ₹3,045
# 1462    ₹3,080
# 1463    ₹1,890
# 1464    ₹3,690
# Name: actual_price, Length: 1465, dtype: str

# %%
print(df["discounted_price"])
# Out:
# 0         ₹399
# 1         ₹199
# 2         ₹199
# 3         ₹329
# 4         ₹154
#          ...
# 1460      ₹379
# 1461    ₹2,280
# 1462    ₹2,219
# 1463    ₹1,399
# 1464    ₹2,863
# Name: discounted_price, Length: 1465, dtype: str

# %% [markdown]
# Removing the rupee symbol and , in the two columns at a time by using below cell

# %%
df[["discounted_price","actual_price"]]=df[["discounted_price","actual_price"]].replace({'₹':"",',':""},regex=True)

# %%
df[["discounted_price","actual_price"]]
# Out:
#      discounted_price actual_price
# 0                 399         1099
# 1                 199          349
# 2                 199         1899
# 3                 329          699
# 4                 154          399
# ...               ...          ...
# 1460              379          919
# 1461             2280         3045
# 1462             2219         3080
# 1463             1399         1890
# 1464             2863         3690
#
# [1465 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   str
#  4   actual_price         1465 non-null   str
#  5   discount_percentage  1465 non-null   str
#  6   rating               1465 non-null   str
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# dtypes: str(16)
# ...

# %%
#Now convert in to Float
df['discounted_price']=df['discounted_price'].astype(float)

# %%
df['actual_price']=df['actual_price'].astype(float)

# %%
df['discounted_price']
# Out:
# 0        399.0
# 1        199.0
# 2        199.0
# 3        329.0
# 4        154.0
#          ...
# 1460     379.0
# 1461    2280.0
# 1462    2219.0
# 1463    1399.0
# 1464    2863.0
# Name: discounted_price, Length: 1465, dtype: float64

# %%
df['actual_price']
# Out:
# 0       1099.0
# 1        349.0
# 2       1899.0
# 3        699.0
# 4        399.0
#          ...
# 1460     919.0
# 1461    3045.0
# 1462    3080.0
# 1463    1890.0
# 1464    3690.0
# Name: actual_price, Length: 1465, dtype: float64

# %% [markdown]
# Doing seperately each column removing the rupee symbol and comma(,)

# %%
#df["discounted_price"]=df["discounted_price"].str.replace("₹","").str.replace(",","").astype(float)

# %%
#df["actual_price"]=df["actual_price"].str.replace("₹","").str.replace(",","").astype(float)

# %%
print(df["actual_price"])
# Out:
# 0       1099.0
# 1        349.0
# 2       1899.0
# 3        699.0
# 4        399.0
#          ...
# 1460     919.0
# 1461    3045.0
# 1462    3080.0
# 1463    1890.0
# 1464    3690.0
# Name: actual_price, Length: 1465, dtype: float64

# %%
df['discount_percentage']
# Out:
# 0       64%
# 1       43%
# 2       90%
# 3       53%
# 4       61%
#        ...
# 1460    59%
# 1461    25%
# 1462    28%
# 1463    26%
# 1464    22%
# Name: discount_percentage, Length: 1465, dtype: str

# %% [markdown]
# Removing the % symbol in the column

# %%
df["discount_percentage"]=df["discount_percentage"].str.replace("%","")
print(df["discount_percentage"])
# Out:
# 0       64
# 1       43
# 2       90
# 3       53
# 4       61
#         ..
# 1460    59
# 1461    25
# 1462    28
# 1463    26
# 1464    22
# Name: discount_percentage, Length: 1465, dtype: str

# %%
df["discount_percentage"]=df["discount_percentage"].astype(float)

# %%
df["discount_percentage"]
# Out:
# 0       64.0
# 1       43.0
# 2       90.0
# 3       53.0
# 4       61.0
#         ...
# 1460    59.0
# 1461    25.0
# 1462    28.0
# 1463    26.0
# 1464    22.0
# Name: discount_percentage, Length: 1465, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   str
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %% [markdown]
# What is meaning of NAN--Not a number
# previosuly 1279 row containg | chracter in my rating column
# aFter applying the errors='coerce--> this | will become as NaN--Not a number

# %%
df["rating"]=pd.to_numeric(df["rating"],errors='coerce')

# %%
# If we do not use coerce we get error
df["rating"]=pd.to_numeric(df["rating"])

# %%
df['rating']
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460    4.0
# 1461    4.1
# 1462    3.6
# 1463    4.0
# 1464    4.3
# Name: rating, Length: 1465, dtype: float64

# %% [markdown]
# .loc[] and .iloc[] #We can check if pipe symbol removed?
# These are indexers-->we can select rows and columns
#
# .loc[]-->labels-->It selects rows and column names .iloc[]-->integer based-->it select rows and column numbers

# %%
df.iloc[0,0]# Here we need one []
# Out:
# 'B07JW9H4J1'

# %%
df.loc[[0,1]]# Here we need two {} will dispaly 1st two rows
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
#
#    actual_price  discount_percentage  rating rating_count  \
# 0        1099.0                 64.0     4.2       24,269
# 1         349.0                 43.0     4.0       43,994
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
# ...

# %%
df.loc[1279] # Here we can check rating = Nan
# Out:
# product_id                                                    B08L12N5H1
# product_name           Eureka Forbes car Vac 100 Watts Powerful Sucti...
# category               Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
# discounted_price                                                  2099.0
# actual_price                                                      2499.0
# discount_percentage                                                 16.0
# rating                                                               NaN
# rating_count                                                         992
# about_product          No Installation is provided for this product|1...
# user_id                AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
# user_name              Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
# review_id              R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
# review_title           Decent product,doesn't pick up sand,Ok ok,Must...
# ...

# %%
df.iloc[1279]# we can check with iloc also
# Out:
# product_id                                                    B08L12N5H1
# product_name           Eureka Forbes car Vac 100 Watts Powerful Sucti...
# category               Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
# discounted_price                                                  2099.0
# actual_price                                                      2499.0
# discount_percentage                                                 16.0
# rating                                                               NaN
# rating_count                                                         992
# about_product          No Installation is provided for this product|1...
# user_id                AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
# user_name              Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
# review_id              R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
# review_title           Decent product,doesn't pick up sand,Ok ok,Must...
# ...

# %%
#Multiple rows 
df.loc[[12,13]]# To see two row with loc
# Out:
#     product_id                                       product_name  \
# 12  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 13  B085DTN6R2  Portronics Konnect CL 20W POR-1067 Type-C to 8...
#
#                                              category  discounted_price  \
# 12  Electronics|HomeTheater,TV&Video|Accessories|C...             219.0
# 13  Computers&Accessories|Accessories&Peripherals|...             350.0
#
#     actual_price  discount_percentage  rating rating_count  \
# 12         700.0                 69.0     4.4     4,26,973
# 13         899.0                 61.0     4.2        2,262
#
#                                         about_product  \
# 12  Flexible, lightweight HDMI cable for connectin...
# 13  [20W PD FAST CHARGING]-It’s supports 20W PD qu...
#
#                                               user_id  \
# 12  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 13  AGUAYQHARAKR2VZTRP276KAGETKQ,AFKTST2773VUOKUHE...
#
# ...

# %%
df.iloc[[12,13]]# To see two row with iloc
# Out:
#     product_id                                       product_name  \
# 12  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 13  B085DTN6R2  Portronics Konnect CL 20W POR-1067 Type-C to 8...
#
#                                              category  discounted_price  \
# 12  Electronics|HomeTheater,TV&Video|Accessories|C...             219.0
# 13  Computers&Accessories|Accessories&Peripherals|...             350.0
#
#     actual_price  discount_percentage  rating rating_count  \
# 12         700.0                 69.0     4.4     4,26,973
# 13         899.0                 61.0     4.2        2,262
#
#                                         about_product  \
# 12  Flexible, lightweight HDMI cable for connectin...
# 13  [20W PD FAST CHARGING]-It’s supports 20W PD qu...
#
#                                               user_id  \
# 12  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 13  AGUAYQHARAKR2VZTRP276KAGETKQ,AFKTST2773VUOKUHE...
#
# ...

# %%
df.loc[1279]
# Out:
# product_id                                                    B08L12N5H1
# product_name           Eureka Forbes car Vac 100 Watts Powerful Sucti...
# category               Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
# discounted_price                                                  2099.0
# actual_price                                                      2499.0
# discount_percentage                                                 16.0
# rating                                                               NaN
# rating_count                                                         992
# about_product          No Installation is provided for this product|1...
# user_id                AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
# user_name              Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
# review_id              R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
# review_title           Decent product,doesn't pick up sand,Ok ok,Must...
# ...

# %%
df.iloc[1279]['rating']# What is there in 1279 rating ?This show only this perticular rating only not whole row
# Out:
# np.float64(nan)

# %%
#now i want to check that what 1279 th row containg in the rating column
print(df.loc[1279,"rating"])
# Out:
# nan

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
#Converting rating_count to float and replacing
df["rating_count"]=df["rating_count"].str.replace(",","").astype(float)

# %%
#If we do not put str will give error
df["rating_count"]=df["rating_count"].replace(",","").astype(float)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %% [markdown]
# Checking nulls

# %%
print(df.isnull())#it returns boolean value
# Out:
#       product_id  product_name  category  discounted_price  actual_price  \
# 0          False         False     False             False         False
# 1          False         False     False             False         False
# 2          False         False     False             False         False
# 3          False         False     False             False         False
# 4          False         False     False             False         False
# ...          ...           ...       ...               ...           ...
# 1460       False         False     False             False         False
# 1461       False         False     False             False         False
# 1462       False         False     False             False         False
# 1463       False         False     False             False         False
# 1464       False         False     False             False         False
#
#       discount_percentage  rating  rating_count  about_product  user_id  \
# ...

# %%
print(df.isnull().sum())
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
#it returns Boolean values True or False
print(df['rating'].isnull())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: rating, Length: 1465, dtype: bool

# %%
#i want only That True value where we got 
print(df[df['rating'].isnull()])
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# 1279        2499.0                 16.0     NaN         992.0
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %% [markdown]
# how to deal the nulls? #### This is from AI Session # 23 start from 12:32 on video ##########################
# we have two columns rating and rating count nulls
#
# why we need to fill the nulls?
#
# 1.We can drop the rows with nulls--it will drops entire row---it removed entires 3 rows
#
# 2.Fill the nulls with any stastical value#mean,median,mode----
#
# 3.Fill the nulls with any fixed or any default value
#
# 1--?only if they are a very few and wont affect our data analysis
# 2--U can prefer any one of the below stats techniques
# mean--average--3.6
# median--middle value---sorting-->take the middle values--2,3,4,4,5,6//here it consider as 4
# mode--most frequent value--4
# 3.depending upon the business prblm and the domain u can go for some fixed value

# %% [markdown]
# If i drop the rows means entire rows for all columns will remove thats why we cant perform to fill the any stats value so choose any one way of filling the nulls in the oprions either 1,2,3.

# %% [markdown]
# #1.drop the rows  ### Not executing because it will delete all three but here are the codes #######
# #df=df.dropna(subset=["rating","rating_count"])
# #1 from rating
# #2 from rating count
# #total 3 rows
# #after droping 3 rows we will get total rows of each column as 1462

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
print(df.isnull().sum())
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
df['rating'].mean()
# Out:
# np.float64(4.096584699453552)

# %%
df['rating_count'].mean()
# Out:
# np.float64(18295.541353383458)

# %% [markdown]
# Filling the nulls # AI Session #23 Video start 18:30 here

# %%
df['rating'].fillna(df['rating'].mean(),inplace=True)
# Out:
# C:\Users\jaiam\AppData\Local\Temp\ipykernel_46860\3424798236.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['rating'].fillna(df['rating'].mean(),inplace=True)
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460    4.0
# 1461    4.1
# 1462    3.6
# 1463    4.0
# 1464    4.3
# ...

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %% [markdown]
# here we get not filled those mean value we have to assing it or follow the below
# procedure of inplace=True

# %%
df.iloc[1279]
# Out:
# product_id                                                    B08L12N5H1
# product_name           Eureka Forbes car Vac 100 Watts Powerful Sucti...
# category               Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
# discounted_price                                                  2099.0
# actual_price                                                      2499.0
# discount_percentage                                                 16.0
# rating                                                               NaN
# rating_count                                                       992.0
# about_product          No Installation is provided for this product|1...
# user_id                AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
# user_name              Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
# review_id              R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
# review_title           Decent product,doesn't pick up sand,Ok ok,Must...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
df['rating'].fillna(df['rating'].mean(),inplace=True)
# Out:
# C:\Users\jaiam\AppData\Local\Temp\ipykernel_46860\3424798236.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['rating'].fillna(df['rating'].mean(),inplace=True)
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460    4.0
# 1461    4.1
# 1462    3.6
# 1463    4.0
# 1464    4.3
# ...

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
#2.Filling with statsical
#df['rating'].fillna(df['rating'].mean(),inplace=True)#simply replaced the inside the dataframe
df['rating_count'].fillna(df['rating_count'].mean(),inplace=True)
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
#3.With fixed value
df['rating'].fillna(0,inplace=True)
df['rating']=df['rating'].fillna(0)#instead of inplace=True parameter
df['rating_count'].fillna(0,inplace=True)
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
#3.With fixed value for rating_count
df['rating_count'].fillna(0,inplace=True)
df['rating_count']=df['rating_count'].fillna(0)#instead of inplace=True parameter
df['rating_count'].fillna(0,inplace=True)
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %% [markdown]
# In above cases we filled the nulls with mean value here i want to check what is that filled value in that particular index
#
# first check where we have nulls--
# ----identify rows that having Nan and by getting their index then store it.
# fill it with mean
# again check those filled values-- view the filled ones

# %%
#Price difference

df['price_diff']=df['actual_price']-df['discounted_price']

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %%
print(df['price_diff'])
# Out:
# 0        700.0
# 1        150.0
# 2       1700.0
# 3        370.0
# 4        245.0
#          ...
# 1460     540.0
# 1461     765.0
# 1462     861.0
# 1463     491.0
# 1464     827.0
# Name: price_diff, Length: 1465, dtype: float64

# %%
print(df['actual_price'].mean())
# Out:
# 5444.990634812287

# %%
#i want highest rated prodcut top 10
#sort_values
highest_rated=df.sort_values(by='rating',ascending=False).head(10)

print(highest_rated['rating'])

#simply update this with product name also
# Out:
# 775     5.0
# 324     5.0
# 174     5.0
# 1201    4.8
# 1145    4.8
# 1299    4.8
# 249     4.7
# 1226    4.7
# 1223    4.7
# 459     4.7
# Name: rating, dtype: float64

# %%
highest_rated
# Out:
#       product_id                                       product_name  \
# 775   B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 324   B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 174   B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 1201  B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# 1145  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
# 1299  B0B53DS4TF  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...
# 249   B09WN3SRC7  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...
# 1226  B0BLC2BYPX  Zuvexa USB Rechargeable Electric Foam Maker - ...
# 1223  B0BM4KTNL1  FIGMENT Handheld Milk Frother Rechargeable, 3-...
# 459   B0B23LW7NV  Spigen EZ Fit Tempered Glass Screen Protector ...
#
#                                                category  discounted_price  \
# 775   Computers&Accessories|Accessories&Peripherals|...             499.0
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'price_diff'],
#       dtype='str')

# %%
print(highest_rated[['rating','product_name']])# I want to print Product Name
# Out:
#       rating                                       product_name
# 775      5.0  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 324      5.0  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 174      5.0  Syncwire LTG to USB Cable for Fast Charging Co...
# 1201     4.8  Oratech Coffee Frother electric, milk frother ...
# 1145     4.8  Swiffer Instant Electric Water Heater Faucet T...
# 1299     4.8  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...
# 249      4.7  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...
# 1226     4.7  Zuvexa USB Rechargeable Electric Foam Maker - ...
# 1223     4.7  FIGMENT Handheld Milk Frother Rechargeable, 3-...
# 459      4.7  Spigen EZ Fit Tempered Glass Screen Protector ...

# %%
#groupby

product_grp=df.groupby(by='category')

print(product_grp.size())
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    1
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   2
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           1
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        2
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           2
#                                                                                                                          ..
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens        2
# ...

# %%
#which category offers the biggest discount
best_dis_category=df.groupby('category')['discount_percentage']

print(best_dis_category)

# %%
print(best_dis_category.mean().sort_values(ascending=False).head(10))
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|CableConnectionProtectors                       90.0
# Electronics|Headphones,Earbuds&Accessories|Earpads                                                               90.0
# Electronics|Mobiles&Accessories|MobileAccessories|Décor|PhoneCharms                                              90.0
# Electronics|Headphones,Earbuds&Accessories|Adapters                                                              88.0
# Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboard&MiceAccessories|DustCovers    87.5
# Electronics|Mobiles&Accessories|MobileAccessories|Mounts|Shower&WallMounts                                       82.0
# Computers&Accessories|Components|InternalHardDrives                                                              80.0
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                          78.5
# ...

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635            47.691468     4.093788
# std         6944.304394   10874.826864            21.635905     0.310598
# min           39.000000      39.000000             0.000000     0.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count    price_diff
# count    1465.000000   1465.000000
# mean    18270.564505   2319.679761
# std     42729.995315   4604.473790
# min         0.000000      0.000000
# 25%      1173.000000    371.000000
# 50%      5178.000000    800.000000
# 75%     17325.000000   1953.000000
# ...

# %% [markdown]
# Implement below requirements
# 1.Which category have the most ratings
# 2.Average ratnig with average discount per category
# 3.Products with no discount
# 4.Most common rating
# 5.Try to identify the very less priced and highly rated

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# ...

# %% [markdown]
# i did lot analyss on top of this ---i want to save that permentn then i go go for to_csv-->

# %%
df.to_csv("C:/Users/jaiam/OneDrive/2026/Training_2026/H2kInfosys-2026/AI_Data/amazon_Fixed.csv")

# %% [markdown]
# #3.With fixed value
# #df['rating'].fillna(0,inplace=True)
# #df['rating']=df['rating'].fillna(0)#instead of inplace=True parameter
# #df['rating_count'].fillna(0,inplace=True)
# #print(df.info())

# %% [markdown]
# In above cases we filled the nulls with mean value here i want to check what is that filled value in that particular index
#
# first check where we have nulls--
# ----identify rows that having Nan and by getting their index then store it.
# fill it with mean
# again check those filled values-- view the filled ones

# %%
#Price difference
