# %% [markdown]
# AI Recording Session # 20 Time start from 29.17 2nd part of Numpy coding
# Pandas:
# Pands one of the ,imp library on python for data handling and analsis.
#
# It is used DAtascience,Data analytics,ML,BIg data....
#
# simply it turns our raw data to strucutred and clean and analyzable form
#
# It also built on top of numpy only.
#
# here we have data structures called Series,Dataframe
#
# -->Easy to use--simple like row and column kind strucutre
# -->It will integrate with other lib---numpy,matplotlib,scikit learn
# -->DAta cleaning--hadnling missing values,duplicates...
# -->Data analysis--filtering,grping,merging,aggeregating
# -->file handling--csv,excel,sql,json,html
#
# Install:
# pip install pandas

# %% [markdown]
# #Series--A single column(1D arraay) with index-->IT uses numpy internally

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30])# By defult Index will start from 0
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s=pd.Series([10,20,30],index=['a','b','c'])
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#Here the data is dict now we want convert this dict to DataFrame

data={"Tech":["AI","bigdata","cloud","devops","ETL tools"],"Age":[22,26,27,34,42],"Location":["USA","India","Japan","china","Aus"]}
#data={"Tech":["AI","bigdata","cloud","devops","ETL tools"],"Age":[22,26,27,34,42],"Location":["USA","India","Japan","china","Aus"]}

# %%
data
# Out:
# {'Tech': ['AI', 'bigdata', 'cloud', 'devops', 'ETL tools'],
#  'Age': [22, 26, 27, 34, 42],
#  'Location': ['USA', 'India', 'Japan', 'china', 'Aus']}

# %% [markdown]
# Data frames:Like a table-->rows and columns
# Pandas built on numpy arrays so here dataframe is collection series objects Again that is internally a numpy array. Default index starts with 0 IF we want to change yes we can change by using index parameter

# %%
df=pd.DataFrame(data,index=['a','b','c','d','e'])
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df1=pd.DataFrame(data)
df1
# Out:
#         Tech  Age Location
# 0         AI   22      USA
# 1    bigdata   26    India
# 2      cloud   27    Japan
# 3     devops   34    china
# 4  ETL tools   42      Aus

# %%
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
data#This will print no structure so we can creatr a Data Frame = df
# Out:
# {'Tech': ['AI', 'bigdata', 'cloud', 'devops', 'ETL tools'],
#  'Age': [22, 26, 27, 34, 42],
#  'Location': ['USA', 'India', 'Japan', 'china', 'Aus']}

# %% [markdown]
# Data frames:Like a table-->rows and columns
# Pandas built on numpy arrays so here dataframe is collection series objects Again that is internally a numpy array. Default index starts with 0 IF we want to change yes we can change by using index parameter

# %%
df=pd.DataFrame(data,index=['a','b','c','d','e'])
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df1=pd.DataFrame(data)# Here did not put any Index sot it will give defult 0,1,2...
df1
# Out:
#         Tech  Age Location
# 0         AI   22      USA
# 1    bigdata   26    India
# 2      cloud   27    Japan
# 3     devops   34    china
# 4  ETL tools   42      Aus

# %%
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %% [markdown]
# #AI Recording session #21 start from here

# %% [markdown]
# Checking properties of dataframe

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()# String will take as Object and Digit as Integer
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, a to e
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tech      5 non-null      str
#  1   Age       5 non-null      int64
#  2   Location  5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 332.0+ bytes

# %%
df.columns
# Out:
# Index(['Tech', 'Age', 'Location'], dtype='str')

# %%
df.describe()#IT applies all stats techniques on integer column here
# Out:
#              Age
# count   5.000000
# mean   30.200000
# std     7.886698
# min    22.000000
# 25%    26.000000
# 50%    27.000000
# 75%    34.000000
# max    42.000000

# %% [markdown]
# ## Indexing
# loc[] and iloc[]:
# loc[]-->Location-->is label based to get the elements iloc[]-->Integer location--> It selects index positions with inetger.
# iloc[]--> Integer location--> It selects index positions with integer.

# %%
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df.loc['a']
# Out:
# Tech         AI
# Age          22
# Location    USA
# Name: a, dtype: object

# %%
df.iloc[0]
# Out:
# Tech         AI
# Age          22
# Location    USA
# Name: a, dtype: object

# %%
df.iloc['a']# We will get eoore This index should be digit in integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.iloc['a']# We will get eoore This index should be digit in integer
#
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1770, in _iLocIndexer._getitem_axis(self, key, axis)
#    1768 key = item_from_zerodim(key)
#    1769 if not is_integer(key):
# -> 1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
# ...

# %%
df1.loc[0] # This will print 1st raw
# Out:
# Tech         AI
# Age          22
# Location    USA
# Name: 0, dtype: object

# %%
df1.iloc[0] # This will get same results
# Out:
# Tech         AI
# Age          22
# Location    USA
# Name: 0, dtype: object

# %%
df.loc['c']
# Out:
# Tech        cloud
# Age            27
# Location    Japan
# Name: c, dtype: object

# %%
df.iloc[2]
# Out:
# Tech        cloud
# Age            27
# Location    Japan
# Name: c, dtype: object

# %%
df.iloc[1:4] # We can use some split also
# Out:
#       Tech  Age Location
# b  bigdata   26    India
# c    cloud   27    Japan
# d   devops   34    china

# %%
df.loc['a':'c']
# Out:
#       Tech  Age Location
# a       AI   22      USA
# b  bigdata   26    India
# c    cloud   27    Japan

# %%
df.iloc[:1]
# Out:
#   Tech  Age Location
# a   AI   22      USA

# %%
df.iloc[:,1]
# Out:
# a    22
# b    26
# c    27
# d    34
# e    42
# Name: Age, dtype: int64

# %%
df.iloc[:] # This will print everything
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df.iloc[:1] #Here no coma so will print only 1st raw
# Out:
#   Tech  Age Location
# a   AI   22      USA

# %%
df.iloc[:,1]# Here with coma and 1 will print Indix and 2nd columan, All the raws and 2nd columan
# Out:
# a    22
# b    26
# c    27
# d    34
# e    42
# Name: Age, dtype: int64

# %%
df.iloc[:,2] #This will print only all locations
# Out:
# a      USA
# b    India
# c    Japan
# d    china
# e      Aus
# Name: Location, dtype: str

# %%
df.iloc[:2] #This will print 1st two raws
# Out:
#       Tech  Age Location
# a       AI   22      USA
# b  bigdata   26    India

# %%
df1
# Out:
#         Tech  Age Location
# 0         AI   22      USA
# 1    bigdata   26    India
# 2      cloud   27    Japan
# 3     devops   34    china
# 4  ETL tools   42      Aus

# %%
df1.loc[:"Age"]
# Out:
#         Tech  Age Location
# 0         AI   22      USA
# 1    bigdata   26    India
# 2      cloud   27    Japan
# 3     devops   34    china
# 4  ETL tools   42      Aus

# %%
df1.loc[:,"Age"]
# Out:
# 0    22
# 1    26
# 2    27
# 3    34
# 4    42
# Name: Age, dtype: int64

# %%
df.loc[['a','b']]#This will print two raws
# Out:
#       Tech  Age Location
# a       AI   22      USA
# b  bigdata   26    India

# %%
df.loc['c'][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.loc['c'][2]
#
# ...

# %%
df.loc['c']['Location']
# Out:
# 'Japan'

# %%
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df.loc['c'][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.loc['c'][2]
#
# ...

# %%
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df.loc['c']['Location']
# Out:
# 'Japan'

# %%
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df.loc['c'][[1,2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.loc['c'][[1,2]]
#
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:991, in Series.__getitem__(self, key)
#     988     key = np.asarray(key, dtype=bool)
#     989     return self._get_rows_with_mask(key)
# --> 991 return self._get_with(key)
#
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1003, in Series._get_with(self, key)
#    1000 elif isinstance(key, tuple):
#    1001     return self._get_values_tuple(key)
# -> 1003 return self.loc[key]
#
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
df.loc['c'][['Age','Location']]
# Out:
# Age            27
# Location    Japan
# Name: c, dtype: object

# %%
df.loc["a":"c"]#inclusive the start and ending labels--a,b,c are included
# Out:
#       Tech  Age Location
# a       AI   22      USA
# b  bigdata   26    India
# c    cloud   27    Japan

# %%
df.loc['c'][2]#This will print only Japan
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df.loc['c'][2]
#
# ...

# %%
df.loc['c'][[1,2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df.loc['c'][[1,2]]
#
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:991, in Series.__getitem__(self, key)
#     988     key = np.asarray(key, dtype=bool)
#     989     return self._get_rows_with_mask(key)
# --> 991 return self._get_with(key)
#
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1003, in Series._get_with(self, key)
#    1000 elif isinstance(key, tuple):
#    1001     return self._get_values_tuple(key)
# -> 1003 return self.loc[key]
#
# File c:\Users\jaiam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
df.loc['c']['Location']
# Out:
# 'Japan'

# %%
df.loc["a":"c"]
# Out:
#       Tech  Age Location
# a       AI   22      USA
# b  bigdata   26    India
# c    cloud   27    Japan

# %%
df
# Out:
#         Tech  Age Location
# a         AI   22      USA
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df.loc[df['Age']>24]# Check some condition
# Out:
#         Tech  Age Location
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %% [markdown]
# C:\Users\jaiam\OneDrive\2026\Training_2026\H2kInfosys-2026\AI_Data

# %% [markdown]
# df=pd.read_csv("C:\\Users\\kumar\\Desktop\\amazon.csv")
# df=pd.read_csv("C:/Users/jaiam/OneDrive/2026/Training_2026\H2kInfosys-2026/AI_Dataamazon.csv")

# %%
df['Age']>24
# Out:
# a    False
# b     True
# c     True
# d     True
# e     True
# Name: Age, dtype: bool

# %%
df.loc[df['Age']>24]
# Out:
#         Tech  Age Location
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df.loc[df.Age>24]
# Out:
#         Tech  Age Location
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df.loc[df.Age>24,"Age"]
# Out:
# b    26
# c    27
# d    34
# e    42
# Name: Age, dtype: int64

# %%
df[df['Age']>24].iloc[:,1]
# Out:
# b    26
# c    27
# d    34
# e    42
# Name: Age, dtype: int64

# %% [markdown]
# #iloc--position based  Start video #20 from 37.51

# %%
df[df["Age"]>24].iloc[1]
# Out:
# Tech        cloud
# Age            27
# Location    Japan
# Name: c, dtype: object

# %%
df[df["Age"]>24]
# Out:
#         Tech  Age Location
# b    bigdata   26    India
# c      cloud   27    Japan
# d     devops   34    china
# e  ETL tools   42      Aus

# %%
df[df["Age"]>24].iloc[:,1]# Here we use iLog outside of condition while loc inside loc condition
# Out:
# b    26
# c    27
# d    34
# e    42
# Name: Age, dtype: int64

# %%
df.iloc[1]# This will print only 1st raw
# Out:
# Tech        bigdata
# Age              26
# Location      India
# Name: b, dtype: object

# %%
df.iloc[[0,2],[1,2]]
#here taking [0,2]--> as rows
#[1,2] as columns
# Out:
#    Age Location
# a   22      USA
# c   27    Japan

# %%
df.iloc[[0,2],[0,2]]
#here taking [0,2]--> as rows
#[1,2] as columns
# Out:
#     Tech Location
# a     AI      USA
# c  cloud    Japan

# %%
df.iloc[[0,2],[0,1,2]]
#here taking [0,2]--> as rows
#[1,2] as columns
# Out:
#     Tech  Age Location
# a     AI   22      USA
# c  cloud   27    Japan

# %%
df.iloc[[0,2],[2]]
#here taking [0,2]--> as rows
#[1,2] as columns
# Out:
#   Location
# a      USA
# c    Japan

# %% [markdown]
# End od AI Session #21
